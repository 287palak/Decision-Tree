# %% [markdown]
# Question 1:

# %%
import pandas as pd
import numpy as np
data = pd.read_csv('/content/penguins.csv')
data
# Out:
#        species     island  bill_length_mm  ...  body_mass_g     sex  year
# 0       Adelie  Torgersen            39.1  ...       3750.0    male  2007
# 1       Adelie  Torgersen            39.5  ...       3800.0  female  2007
# 2       Adelie  Torgersen            40.3  ...       3250.0  female  2007
# 3       Adelie  Torgersen             NaN  ...          NaN     NaN  2007
# 4       Adelie  Torgersen            36.7  ...       3450.0  female  2007
# ..         ...        ...             ...  ...          ...     ...   ...
# 339  Chinstrap      Dream            55.8  ...       4000.0    male  2009
# 340  Chinstrap      Dream            43.5  ...       3400.0  female  2009
# 341  Chinstrap      Dream            49.6  ...       3775.0    male  2009
# 342  Chinstrap      Dream            50.8  ...       4100.0    male  2009
# 343  Chinstrap      Dream            50.2  ...       3775.0  female  2009
#
# [344 rows x 8 columns]

# %%
data = data.dropna()
data
# Out:
#        species     island  bill_length_mm  ...  body_mass_g     sex  year
# 0       Adelie  Torgersen            39.1  ...       3750.0    male  2007
# 1       Adelie  Torgersen            39.5  ...       3800.0  female  2007
# 2       Adelie  Torgersen            40.3  ...       3250.0  female  2007
# 4       Adelie  Torgersen            36.7  ...       3450.0  female  2007
# 5       Adelie  Torgersen            39.3  ...       3650.0    male  2007
# ..         ...        ...             ...  ...          ...     ...   ...
# 339  Chinstrap      Dream            55.8  ...       4000.0    male  2009
# 340  Chinstrap      Dream            43.5  ...       3400.0  female  2009
# 341  Chinstrap      Dream            49.6  ...       3775.0    male  2009
# 342  Chinstrap      Dream            50.8  ...       4100.0    male  2009
# 343  Chinstrap      Dream            50.2  ...       3775.0  female  2009
#
# [333 rows x 8 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.distplot(a=data.bill_length_mm, hist=False)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(a=data.bill_depth_mm, hist=False)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(a=data.flipper_length_mm, hist=False)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
features = ['body_mass_g', 'year']
data[features].hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fe89cd4cf10>,
# ...
#       dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le_species = LabelEncoder()
le_island = LabelEncoder()
le_sex = LabelEncoder()
le_year=LabelEncoder()

# %%
data['island_n'] = le_island.fit_transform(data['island'])
data['sex_n'] = le_sex.fit_transform(data['sex'])
data['year_n'] = le_year.fit_transform(data['year'])
data['species_n'] = le_species.fit_transform(data['species'])
data
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
data_n=data.drop(['species','island','sex','year'],axis='columns')
target=data['species_n']
data_n
# Out:
#      bill_length_mm  bill_depth_mm  flipper_length_mm  ...  sex_n  year_n  species_n
# 0              39.1           18.7              181.0  ...      1       0          0
# 1              39.5           17.4              186.0  ...      0       0          0
# 2              40.3           18.0              195.0  ...      0       0          0
# 4              36.7           19.3              193.0  ...      0       0          0
# 5              39.3           20.6              190.0  ...      1       0          0
# ..              ...            ...                ...  ...    ...     ...        ...
# 339            55.8           19.8              207.0  ...      1       2          1
# 340            43.5           18.1              202.0  ...      0       2          1
# 341            49.6           18.2              193.0  ...      1       2          1
# 342            50.8           19.0              210.0  ...      1       2          1
# ...

# %%
from sklearn.model_selection import train_test_split
X = data_n.values[:, 0:8]; 
Y = data_n.values[:, 7:8];
X_train, X_test, y_train, y_test = train_test_split( X, Y, test_size = 0.2, random_state = 42)
data_n
# Out:
#      bill_length_mm  bill_depth_mm  flipper_length_mm  ...  sex_n  year_n  species_n
# 0              39.1           18.7              181.0  ...      1       0          0
# 1              39.5           17.4              186.0  ...      0       0          0
# 2              40.3           18.0              195.0  ...      0       0          0
# 4              36.7           19.3              193.0  ...      0       0          0
# 5              39.3           20.6              190.0  ...      1       0          0
# ..              ...            ...                ...  ...    ...     ...        ...
# 339            55.8           19.8              207.0  ...      1       2          1
# 340            43.5           18.1              202.0  ...      0       2          1
# 341            49.6           18.2              193.0  ...      1       2          1
# 342            50.8           19.0              210.0  ...      1       2          1
# ...

# %%
def entropy(y):
        cl = np.unique(y)
        entropy = 0
        for i in cl:
            p_i = len(y[y == i]) / len(y)
            entropy += -p_i * np.log2(p_i)
        return entropy
        
entropy(X_train)
data_n['sex_n'][339]
data_n
# Out:
#      bill_length_mm  bill_depth_mm  flipper_length_mm  ...  sex_n  year_n  species_n
# 0              39.1           18.7              181.0  ...      1       0          0
# 1              39.5           17.4              186.0  ...      0       0          0
# 2              40.3           18.0              195.0  ...      0       0          0
# 4              36.7           19.3              193.0  ...      0       0          0
# 5              39.3           20.6              190.0  ...      1       0          0
# ..              ...            ...                ...  ...    ...     ...        ...
# 339            55.8           19.8              207.0  ...      1       2          1
# 340            43.5           18.1              202.0  ...      0       2          1
# 341            49.6           18.2              193.0  ...      1       2          1
# 342            50.8           19.0              210.0  ...      1       2          1
# ...

# %%
import warnings
warnings.filterwarnings('ignore')

def cont_to_cat(data,y):
  data_c = data[y]
  mi = min(data_c)
  ma = max(data_c)
  th = mi
  t = mi/2+(ma/2)
  info_g = 0

  for i in data[y]:

    if(i == mi or i == ma):
      continue
    dt = data.copy()
    dt['z'] = pd.cut(dt[y],bins = [mi,i,ma],labels = [0,1]) 
    ct=0
    ct_g=0
    
    for j in dt['z']:
      if(j==1):
        ct=ct+1
      else:
        ct_g=ct_g+1
    info_g2 = entropy(X_train) - ((ct*entropy(dt['z']))+(ct_g*entropy(dt['z'])))/len(y_train)
    if(info_g<info_g2):
      th=i
      info_g = info_g2
  
 
  data[y] = pd.cut( data[y], bins = [mi,t,ma], labels = [0,1] , duplicates='drop')
  return data
cont_to_cat(data_n,'bill_length_mm')
cont_to_cat(data_n,'bill_depth_mm')
cont_to_cat(data_n,'flipper_length_mm')
data_n
# Out:
#     bill_length_mm bill_depth_mm flipper_length_mm  ...  sex_n  year_n  species_n
# 0                0             1                 0  ...      1       0          0
# 1                0             1                 0  ...      0       0          0
# 2                0             1                 0  ...      0       0          0
# 4                0             1                 0  ...      0       0          0
# 5                0             1                 0  ...      1       0          0
# ..             ...           ...               ...  ...    ...     ...        ...
# 339              1             1                 1  ...      1       2          1
# 340              0             1                 1  ...      0       2          1
# 341              1             1                 0  ...      1       2          1
# 342              1             1                 1  ...      1       2          1
# ...

# %%
class Node():
    def __init__(self, fti=None, thres=None, left=None, right=None, i_g=None, val=None):
        self.left = left
        self.right = right
        self.fti = fti              #feature index
        self.i_g = i_g              #information gain
        self.val = val
        self.thres = thres          #threshold

# %%
class DTC():
    def __init__(self, mss=2, max_depth=2):
        self.max_depth = max_depth
        self.root = None
        self.mss = mss

    def build_tree(self, data, curr_depth=0):
        X, Y = data[:,:-1], data[:,-1]
        n_samples, n_features = np.shape(X)

        '''Question 1: (4):'''
        '''condition to check that the tree does not exceed the max depth''' 

        if n_samples >= self.mss and curr_depth<=self.max_depth:
            best_split = self.get_best_split(data, n_samples, n_features) 

            if best_split["info_gain"]>0:
                left_subtree = self.build_tree(best_split["dataset_left"], curr_depth+1)
                right_subtree = self.build_tree(best_split["dataset_right"], curr_depth+1)
                return Node(best_split["feature_index"], best_split["threshold"], left_subtree, right_subtree, best_split["info_gain"])
        Y = list(Y)
        leaf_value = max(Y, key=Y.count)
        return Node(val=leaf_value)
    
    def get_best_split(self, data, n_samples, n_features):
        best_split = {}
        max_info_gain = -float("inf")
        for feature_index in range(n_features):
            feature_values = data[:, feature_index]
            possible_thresholds = np.unique(feature_values)
            for threshold in possible_thresholds:
              dataset_left = np.array([row for row in data if row[feature_index]<=threshold])
              dataset_right = np.array([row for row in data if row[feature_index]>threshold])
              if len(dataset_left)>0 and len(dataset_right)>0:
                    y, left_y, right_y = data[:, -1], dataset_left[:, -1], dataset_right[:, -1]
                    weight_l = len(left_y)/len(y)
                    weight_r = len(right_y)/len(y)
                    gain = entropy(y) - (weight_l * entropy(left_y) + weight_r * entropy(right_y))    
                    curr_info_gain = gain
                    if curr_info_gain>max_info_gain:
                        best_split["feature_index"] = feature_index
                        best_split["threshold"] = threshold
                        best_split["dataset_left"] = dataset_left
                        best_split["dataset_right"] = dataset_right
                        best_split["info_gain"] = curr_info_gain
                        max_info_gain = curr_info_gain
        return best_split
    
    '''Question 1: (5):'''
    def fit(self, X, Y):    
        dataset = np.concatenate((X, Y), axis=1)
        self.root = self.build_tree(dataset)

    '''Question 1: (6):'''
    def predict(self, X):
        pred = [self.prediction(x, self.root) for x in X]
        return pred
    
    def prediction(self, x, tree):
        if tree.val!=None: return tree.val
        feature_val = x[tree.fti]
        if feature_val<=tree.thres:
            return self.prediction(x, tree.left)
        else:
            return self.prediction(x, tree.right)

# %%
classifier = DTC(mss=4, max_depth=5)
classifier.fit(X_train, y_train)

# %%
Y_pred = classifier.predict(X_test) 
from sklearn.metrics import accuracy_score
a = accuracy_score(y_test,Y_pred)
a
# Out:
# 1.0

# %% [markdown]
# Question 2:

# %%
import numpy as np 
import matplotlib.pyplot as plt
import pandas as pd 
data = pd.read_csv('/content/ENB2012_data.csv')
data
# Out:
#        X1     X2     X3      X4   X5  X6   X7  X8     Y1
# 0    0.98  514.5  294.0  110.25  7.0   2  0.0   0  15.55
# 1    0.98  514.5  294.0  110.25  7.0   3  0.0   0  15.55
# 2    0.98  514.5  294.0  110.25  7.0   4  0.0   0  15.55
# 3    0.98  514.5  294.0  110.25  7.0   5  0.0   0  15.55
# 4    0.90  563.5  318.5  122.50  7.0   2  0.0   0  20.84
# ..    ...    ...    ...     ...  ...  ..  ...  ..    ...
# 763  0.64  784.0  343.0  220.50  3.5   5  0.4   5  17.88
# 764  0.62  808.5  367.5  220.50  3.5   2  0.4   5  16.54
# 765  0.62  808.5  367.5  220.50  3.5   3  0.4   5  16.44
# 766  0.62  808.5  367.5  220.50  3.5   4  0.4   5  16.48
# 767  0.62  808.5  367.5  220.50  3.5   5  0.4   5  16.64
#
# [768 rows x 9 columns]

# %%
data = data.dropna()
data
# Out:
#        X1     X2     X3      X4   X5  X6   X7  X8     Y1
# 0    0.98  514.5  294.0  110.25  7.0   2  0.0   0  15.55
# 1    0.98  514.5  294.0  110.25  7.0   3  0.0   0  15.55
# 2    0.98  514.5  294.0  110.25  7.0   4  0.0   0  15.55
# 3    0.98  514.5  294.0  110.25  7.0   5  0.0   0  15.55
# 4    0.90  563.5  318.5  122.50  7.0   2  0.0   0  20.84
# ..    ...    ...    ...     ...  ...  ..  ...  ..    ...
# 763  0.64  784.0  343.0  220.50  3.5   5  0.4   5  17.88
# 764  0.62  808.5  367.5  220.50  3.5   2  0.4   5  16.54
# 765  0.62  808.5  367.5  220.50  3.5   3  0.4   5  16.44
# 766  0.62  808.5  367.5  220.50  3.5   4  0.4   5  16.48
# 767  0.62  808.5  367.5  220.50  3.5   5  0.4   5  16.64
#
# [768 rows x 9 columns]

# %%
X = data.values[:, 0:8] 
Y = data.values[:, 8]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split( X, Y, test_size = 0.2, random_state = 100)
X_val, X_train, y_val, y_train = train_test_split( X_train, y_train, test_size = 0.875, random_state = 100)
print(len(X_train))
print(len(X_val))
print(len(X_test))
# Out:
# 538
# 76
# 154

# %%
from sklearn.tree import DecisionTreeRegressor 

lst=[]
lst2=[]
arr1 = np.arange(10)
arr2 = np.arange(10)
for i in range(1,10):
  regressor = DecisionTreeRegressor(max_depth=i,random_state = 100)
  regressor.fit(X_train,y_train)
  y_pre=regressor.predict((X_test))
  from sklearn.metrics import mean_squared_error
  mse= mean_squared_error(y_test,y_pre)
  arr2[i]=mse
  print("the value of max depth is",i)
  print("MSE associated with this value is ",mse)
import matplotlib.pyplot as plt
x = arr1
y = arr2
plt.plot(x, y)
plt.xlabel('max_depth')
plt.ylabel('Mean_square_error')
plt.show()
# Out:
# the value of max depth is 1
# MSE associated with this value is  20.161854700093613
# the value of max depth is 2
# MSE associated with this value is  11.125915187256803
# the value of max depth is 3
# MSE associated with this value is  5.414840995520459
# the value of max depth is 4
# MSE associated with this value is  2.7456640404509502
# the value of max depth is 5
# MSE associated with this value is  1.0140750253104986
# the value of max depth is 6
# MSE associated with this value is  0.32100083776175137
# the value of max depth is 7
# MSE associated with this value is  0.23344401003209025
# the value of max depth is 8
# MSE associated with this value is  0.2682728533638919
# the value of max depth is 9
# MSE associated with this value is  0.30543288200058155

# %%
lst=[]
lst2=[]
arr1 = np.arange(10)
arr2 = np.arange(10)
for i in range(1,10):
  regressor = DecisionTreeRegressor(max_depth=7,min_samples_leaf=i,random_state = 100)
  regressor.fit(X_train,y_train)
  y_pre=regressor.predict((X_test))
  from sklearn.metrics import mean_squared_error
  mse= mean_squared_error(y_test,y_pre)
  arr2[i]=mse
  print("the value of min sample leaves",i)
  print("MSE associated with this value is ",mse)
import matplotlib.pyplot as plt
x = arr1
y = arr2
plt.plot(x, y)
plt.xlabel('min_samples_leaf')
plt.ylabel('Mean_square_error')
plt.show()
# Out:
# the value of min sample leaves 1
# MSE associated with this value is  0.23344401003209025
# the value of min sample leaves 2
# MSE associated with this value is  0.30762689459197523
# the value of min sample leaves 3
# MSE associated with this value is  0.31525364543279655
# the value of min sample leaves 4
# MSE associated with this value is  0.3012419161710339
# the value of min sample leaves 5
# MSE associated with this value is  0.27887204917841735
# the value of min sample leaves 6
# MSE associated with this value is  1.0155980983709383
# the value of min sample leaves 7
# MSE associated with this value is  0.8811632807336212
# the value of min sample leaves 8
# MSE associated with this value is  0.8743841509164576
# the value of min sample leaves 9
# MSE associated with this value is  0.9193013681946584

# %%
import warnings
warnings.filterwarnings('ignore')
from sklearn.model_selection import cross_val_score
kfold_train_score = cross_val_score(regressor,X_train,y_train,scoring='neg_mean_squared_error',cv=5)
kfold_test_score = cross_val_score(regressor,X_test,y_test,scoring='neg_mean_squared_error',cv=5)
print((kfold_train_score))
print(kfold_test_score)
# Out:
# [-1.28657134 -2.41744427 -1.80331613 -1.73407182 -2.2589229 ]
# [-7.88364585 -7.12234838 -3.37898417 -4.90406277 -9.77197377]

# %%
from sklearn import tree
fig = plt.figure(figsize=(25,20))
t = tree.plot_tree(regressor, feature_names=X,class_names=Y, filled=True)
